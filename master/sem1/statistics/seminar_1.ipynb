# %% [markdown]
# # Seminar 1

# %%
import scipy.stats as stats
poisson_dist = stats.poisson(5)
poisson_dist.cdf(9)

# %% [markdown]
# ![image.png](attachment:52ec7a5d-9b8a-4fb0-8a37-d88a63a9faac.png)

# %% [markdown]
# $hi$
