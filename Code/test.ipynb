# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# NVIDIA GeForce RTX 2060

# %%
import nibabel as nib
import os
import matplotlib.pylab as plt

cwd = os.getcwd()
print(cwd)
#path = '../Datasets/ADNI/002_S_0295/MPR__GradWarp__B1_Correction__N3__SCALED/2006-04-18_08_20_30.0/I45108/ADII_002_S_0295_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20070319113623975_S13408_I45108.nii'
path = 'Datasets\\ADNI\\002_S_0295\\MPR__GradWarp__B1_Correction__N3__SCALED\\2007-05-25_07_12_36.0.nii'

some_path = os.path.join(cwd, path)
print(some_path)

img = nib.load(some_path).get_fdata()
img.shape
plt.style.use('default')
fig, axes = plt.subplots(10,10, figsize=(13,13))
for i, ax in enumerate(axes.reshape(-1)):
    ax.imshow(img[:,:,1 + i])
plt.show()
# Out:
# d:\Facultate\anul_3\ELL\Code
# d:\Facultate\anul_3\ELL\Code\Datasets\ADNI\002_S_0295\MPR__GradWarp__B1_Correction__N3__SCALED\2007-05-25_07_12_36.0.nii
